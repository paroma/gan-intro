# %%
from gan_SL import *
# %matplotlib inline

#500 steps, disc pre-trained with gaussian @mu=4
train_SL(num_steps=501,log_every=500)
# Out:
# 0: 1.55491542816	3.90552210808
# 500: 1.32114255428	0.818000733852

# %%
from gan_SL import *
# %matplotlib inline

#2500 steps, disc pre-trained with gaussian @mu=4
train_SL(num_steps=2500,log_every=500)
# Out:
# 0: 1.55491542816	3.90552210808
# 500: 1.32114255428	0.818000733852
# 1000: 0.76223897934	2.01988863945
# 1500: 0.739578068256	2.29586076736
# 2000: 0.741162955761	2.40478157997

# %%
from gan_SL import *
# %matplotlib inline

#10000 steps, disc pre-trained with gaussian @mu=4
train_SL(num_steps=10000,log_every=500)
# Out:
# 0: 1.55491542816	3.90552210808
# 500: 1.32114255428	0.818000733852
# 1000: 0.76223897934	2.01988863945
# 1500: 0.739578068256	2.29586076736
# 2000: 0.741162955761	2.40478157997
# 2500: 0.734322965145	2.49190688133
# 3000: 0.727845132351	2.50646901131
# 3500: 0.694213867188	2.57484745979
# 4000: 0.729171037674	2.55022501945
# 4500: 0.714067280293	2.5705537796
# 5000: 0.702101051807	2.58799815178
# 5500: 0.680095255375	2.60933017731
# 6000: 0.682497799397	2.60634064674
# 6500: 0.719128072262	2.61272501945
# 7000: 0.705161035061	2.62743782997
# 7500: 0.674787223339	2.64538002014
# 8000: 0.691747844219	2.63653731346
# 8500: 0.714348971844	2.6197655201
# 9000: 0.719496309757	2.60942912102
# 9500: 0.699925243855	2.59953665733

# %%
from gan_SL import *
# %matplotlib inline

#500 steps, disc pre-trained with gaussian @mu=4 with minibatch
train_SL(num_steps=501,log_every=500, minibatch=True)
# Out:
# 0: 1.87505352497	1.43351066113
# 500: 0.663126528263	1.56797969341

# %%
from gan_SL import *
# %matplotlib inline

#10000 steps, disc pre-trained with gaussian @mu=4 with minibatch
train_SL(num_steps=10000,log_every=500, minibatch=True)
# Out:
# 0: 1.87505352497	1.43351066113
# 500: 0.663126528263	1.56797969341
# 1000: 0.348455071449	2.24984765053
# 1500: 0.695331096649	1.94836950302
# 2000: 0.716957747936	1.86992204189
# 2500: 1.14167368412	1.52041566372
# 3000: 0.972842216492	1.42363393307
# 3500: 1.00790369511	1.42687356472
# 4000: 1.22771608829	1.32229840755
# 4500: 1.21477925777	1.29904615879
# 5000: 1.01478767395	1.24966013432
# 5500: 1.13147687912	1.14936506748
# 6000: 1.04976713657	1.1534923315
# 6500: 0.720035254955	1.16511249542
# 7000: 1.00419259071	1.09504139423
# 7500: 1.03363227844	1.06302976608
# 8000: 0.984168052673	1.07320141792
# 8500: 1.11103498936	1.06810724735
# 9000: 1.01924097538	1.06108748913
# 9500: 1.04217278957	1.06067419052

# %%
from gan_SL_small import *
# %matplotlib inline

#500 steps, disc pre-trained with gaussian @mu=4 with minibatch 
#but for only mu=-4
train_SL(num_steps=501,log_every=500, minibatch=True)
# Out:
# 0: 5.23921442032	2.76096844673
# 500: 0.00706553598866	5.91631555557

# %%
from gan_SL_small import *
# %matplotlib inline

#2500 steps, disc pre-trained with gaussian @mu=4 with minibatch 
#but for only mu=-4
train_SL(num_steps=2500,log_every=500, minibatch=True)
# Out:
# 0: 5.23921442032	2.76096844673
# 500: 0.00706553598866	5.91631555557
# 1000: 0.00504307262599	6.30854034424
# 1500: 0.00432844506577	6.48323011398
# 2000: 0.00384087697603	6.66187477112

# %%
from gan_SL_small import *
# %matplotlib inline

#5000 steps, disc pre-trained with gaussian @mu=4 with minibatch 
#but for only mu=-4
train_SL(num_steps=5000,log_every=500, minibatch=True)
# Out:
# 0: 5.23921442032	2.76096844673
# 500: 0.00706553598866	5.91631555557
# 1000: 0.00504307262599	6.30854034424
# 1500: 0.00432844506577	6.48323011398
# 2000: 0.00384087697603	6.66187477112
# 2500: 0.00437356205657	6.75346899033
# 3000: 0.00350166740827	6.74537229538
# 3500: 0.00351092382334	6.85438919067
# 4000: 0.00345572573133	6.87854242325
# 4500: 0.00350143457763	6.87269735336

# %%
from gan_SL_small import *
# %matplotlib inline

#10000 steps, disc pre-trained with gaussian @mu=4 with minibatch 
#but for only mu=-4
train_SL(num_steps=10000,log_every=500, minibatch=True)
# Out:
# 0: 5.23921442032	2.76096844673
# 500: 0.00706553598866	5.91631555557
# 1000: 0.00504307262599	6.30854034424
# 1500: 0.00432844506577	6.48323011398
# 2000: 0.00384087697603	6.66187477112
# 2500: 0.00437356205657	6.75346899033
# 3000: 0.00350166740827	6.74537229538
# 3500: 0.00351092382334	6.85438919067
# 4000: 0.00345572573133	6.87854242325
# 4500: 0.00350143457763	6.87269735336
# 5000: 0.00315517070703	6.83272600174
# 5500: 0.00313044595532	6.93156814575
# 6000: 0.00315745989792	6.96579408646
# 6500: 0.00294088758528	6.96286773682
# 7000: 0.00295285880566	7.0018196106
# 7500: 0.00304451189004	7.02528142929
# 8000: 0.0030066173058	6.99992513657
# 8500: 0.00279142265208	7.01791191101
# 9000: 0.00277422671206	7.02208662033
# 9500: 0.0028750449419	7.00959062576
